# %%
import os
import requests

# %%
#Get pdf path
pdf_path = "../data/human_nutrition.pdf"

if not os.path.exists(pdf_path):
    print(f"File not found at {pdf_path}, downloading...")

    #The url of the pdf we want to download
    url = "https://pressbooks.oer.hawaii.edu/humannutrition2/open/download"

    #Get the only the filename from the path
    filename = pdf_path.split("/")[-1]

    #send a GET request to the url
    response = requests.get(url)

    if response.status_code == 200:
        #open the file in binary write mode and save the content to it
        with open(filename, "wb") as file:
            file.write(response.content)
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

else:
    print(f"File {pdf_path} does exist")
# Out:
# File ../data/human_nutrition.pdf does exist

# %% [markdown]
# PDF Text EXTRACTION

# %%
import fitz  #PyMuPDF - for scraping pdfs - only for digital formats
from tqdm.auto import tqdm

def text_formatter(text:str) -> str:
    """ Performs minor formatting on text"""
    #replace newlines with spaces and strip whitespace
    cleaned_text = text.replace("\n", " ").strip()

    # other potential textformatting
    return cleaned_text

def open_and_read_pdf(pdf_path:str) -> list:
    """Opens a pdf, reads its text page by page, and collects statistics.
    
    Returns:
        list[dict]: A list of dictionaries, each containing the page number
        (adjusted), character count, word count, sentence count, token count 
        and the extracted text for each page.
    """
    
    pages_and_texts = []
    with fitz.open(pdf_path) as doc: #context manager - it automatically closes the document(pdf) after the block is executed
        for page_number, page in tqdm(enumerate(doc)):
            text = page.get_text() # get plain text encoded as UTF-8
            text = text_formatter(text) #format the text
            pages_and_texts.append({"page_number": page_number - 41, #adjust page number since our PDF starts at page 42
                                    "page_char_count": len(text),
                                    "page_word_count": len(text.split(" ")),
                                    "page_sentence_count_raw": len(text.split(". ")),
                                    "page_token_count":len(text)/4, # 1 token = ~4 chars
                                    "text": text})
    
    return pages_and_texts

pages_and_texts = open_and_read_pdf(pdf_path)
# Out:
# 0it [00:00, ?it/s]

# %%
import random 
random.sample(pages_and_texts, k=3)
# Out:
# [{'page_number': 563,
#   'page_char_count': 1487,
#   'page_word_count': 257,
#   'page_sentence_count_raw': 10,
#   'page_token_count': 371.75,
# ...

# %% [markdown]
# ## Chunking Strategy 1: FIXED SIZE Chunking

# %%
def chunk_text(text:str, chunk_size:int = 500) -> list:
    """
    Splits text into chunk of approx 'chunk_size' characters.
    """

    chunks = []
    current_chunk = ''
    words = text.split() #list of words

    for word in words:
        #Check if addding the word exceeds the chunk size
        if(len(current_chunk) + len(word) + 1 <= chunk_size):
            current_chunk += (word + " ")
        else:
            #store the finished chunk and start a new one
            chunks.append(current_chunk.strip())
            current_chunk = word + " "

    #add the last chunk
    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

def chunk_pdf_pages(pages_and_texts:list, chunk_size:int = 500) -> list:
    """
    Takes pdf pages with text and splits them into chunks.
    Returns a list of dicts with page_number, chunk_index, and chunk_text.
    """

    all_chunks = []
    for page in pages_and_texts:
        page_number = page["page_number"]
        page_text = page["text"]

        chunks = chunk_text(page_text, chunk_size)
        for i, chunk in enumerate(chunks):
            all_chunks.append({
                "page_number": page_number,
                "chunk_index": i,
                "chunk_char_count": len(chunk),
                "chunk_word_count": len(chunk.split()),
                "chunk_token_count": len(chunk)/4,  #token estimated
                "chunk_text": chunk
            })
        
    return all_chunks

#Exemple usage
fixed_chunked_pages = chunk_pdf_pages(pages_and_texts = pages_and_texts, chunk_size = 500)
print(f"Total chunks: {len(fixed_chunked_pages)}")
print(f"First chunk ( page {fixed_chunked_pages[0]['page_number']}): {fixed_chunked_pages[0]['chunk_text'][:100]}")
# Out:
# Total chunks: 3321
# First chunk ( page -41): Human Nutrition: 2020 Edition

# %%
import random, textwrap

#------------Sampling & Pretty Printing------------

def _scattered_indices(n: int, k: int, jitter_frac: float = 0.08) -> list:
    """Evenly spaced anchors + random jitter -> indices scattered across [0, n-1]"""

    if k <= 0:
        return []
    if k == 1:
        return [random.randrange(n)]
    anchors = [int(round(i * (n - 1) / (k - 1))) for i in range(k)]
    out,seen = [],set()
    radius = max(1, int(jitter_frac))
    for a in anchors:
        lo, hi = max(0, a - radius), min(n - 1, a + radius)
        j = random.randint(lo, hi)
        if j not in seen:
            out.append(j); seen.add(j)
    while len(out) < k:
        r = random.randrange(n)
        if r not in seen:
            out.append(r); seen.add(r)
    return out

def _draw_boxed_chunk(c: dict, wrap_at: int = 96) -> str:
    header = (
        f" Chunk p{c['page_number']} - idx {c['chunk_index']}  |  "
        f"chars {c['chunk_char_count']} - words {c['chunk_word_count']} -  ~tokens {c['chunk_token_count']} "
    )

    wrapped_lines = textwrap.wrap(
        c["chunk_text"], width=wrap_at, break_long_words = False,replace_whitespace = False
        )
    context_width = max([0, *map(len, wrapped_lines)])
    box_width = max(len(header), context_width + 2)

    top = "||" + "=" * (box_width) + "||"
    hline = "||" + header.ljust(box_width) + "||"
    sep = "||" + "-" * (box_width) + "||"
    body = "\n".join("|| " + line.ljust(box_width - 2) + " ||" for line in wrapped_lines) or \
        ("|| " + "".ljust(box_width - 2) + " ||")
    bottom = "||" + "=" * (box_width) + "||"
    return "\n".join([top, hline, sep, body, bottom])


def show_random_chunks(pages_and_texts:list, chunk_size:int = 500, k: int = 5, seed: int | None = 42):
    if seed is not None:
        random.seed(seed)
    all_chunks = chunk_pdf_pages(pages_and_texts, chunk_size)
    if not all_chunks:
        print("No chunks to display.");
        return
    idxs = _scattered_indices(len(all_chunks), k)
    print(f"Showing {len(idxs)} scattered random chunks out of {len(all_chunks)} total: \n")
    for i, idx in enumerate(idxs,1):
        print(f"#{i}")
        print(_draw_boxed_chunk(all_chunks[idx]))
        print()


#---------Run--------

assert 'pages_and_texts' in globals(), "Run: pages_and_texts = open_and_read_pdf(pdf_path = pdf_path) first"
show_random_chunks(pages_and_texts, chunk_size = 500, k = 5, seed = 42)
# Out:
# Showing 5 scattered random chunks out of 3321 total:
#
# #1
# ||===========================================================||
# || Chunk p-41 - idx 0  |  chars 29 - words 4 -  ~tokens 7.25 ||
# ||-----------------------------------------------------------||
# || Human Nutrition: 2020 Edition                             ||
# ||===========================================================||
#
# #2
# ||=================================================================================================||
# || Chunk p279 - idx 2  |  chars 499 - words 71 -  ~tokens 124.75                                   ||
# ||-------------------------------------------------------------------------------------------------||
# || consuming products with artificial sweeteners decreases weight. In fact, some studies suggest   ||
# || the intense sweetness of these products increases appetite for sweet foods and may lead to      ||
# ...

# %% [markdown]
# ## Chunking Strategy 2: SEMANTIC Chunking

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity 
import numpy as np
import nltk
nltk.download('punkt_tab')
#Load once globally
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
 
def semantic_chunk_text(text: str, similarity_threshold: float = 0.75, max_tokens: int = 500)-> list:
    """
    Splits text into semantic chunks based on sentence similarity and max token lenght
    """
    #break the page into sentences
    sentences = nltk.sent_tokenize(text) #list
    if not sentences:
        return []
    
    embeddings = semantic_model.encode(sentences)
    
    chunks = []
    current_chunk = [sentences[0]]
    current_embeddings  = embeddings[0]

    for i in range(1, len(sentences)):
        #[0][0] takes the value of the cosine similarity
        sim = cosine_similarity([current_embeddings], [embeddings[i]])[0][0]
        chunk_token_count = len(" ".join(current_chunk)) // 4

        if sim >= similarity_threshold and chunk_token_count < max_tokens:
            current_chunk.append(sentences[i])
            #mean of the embeddings chunk
            #I keep only the mean of the embeedings of the chunk(not all the embeddings)
            #each chunk will have only one embedding(the mean of the similar embeddings)
            current_embeddings = np.mean([current_embeddings, embeddings[i]], axis = 0)
        else:
            chunks.append(" ".join(current_chunk)) #string with the current chunk
            current_chunk = [sentences[i]]
            current_embeddings = embeddings[i]

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks
                                
    
from tqdm.auto import tqdm

def semantic_chunk_pdf_pages(pages_and_texts:list, similarity_threshold: float = 0.75, max_tokens: int = 500) -> list:
    """
    Takes pdf pages with text and splits them into semantic chunks.
    Returns a list of dicts with page_number, chunk_index, and chunk_text.
    """

    all_chunks = []
    for page in tqdm(pages_and_texts, desc = "Semantic Chunking"):
        page_number = page["page_number"]
        page_text = page["text"]

        chunks = semantic_chunk_text(page_text, similarity_threshold, max_tokens)

        for i,chunk in enumerate(chunks):
            all_chunks.append({
                "page_number": page_number,
                "chunk_index": i,
                "chunk_char_count": len(chunk),
                "chunk_word_count": len(chunk.split()),
                "chunk_token_count": len(chunk)/4,
                "chunk_text": chunk
            })

    return all_chunks
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/tybyboiciuc/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import nltk

semantic_chunk_pages = semantic_chunk_pdf_pages(pages_and_texts, similarity_threshold = 0.75, max_tokens = 500)

print(f"Total semantic chunks: {len(semantic_chunk_pages)}")
print(f"First semantic chunk page {semantic_chunk_pages[0]['page_number']}")
print(semantic_chunk_pages[0]['chunk_text'][:200])
# Out:
# Semantic Chunking:   0%|          | 0/1208 [00:00<?, ?it/s]
# Total semantic chunks: 12016
# First semantic chunk page -41
# Human Nutrition: 2020 Edition

# %%
import torch
import torch.nn.functional as F
device = "mps" if torch.backends.mps.is_available() else "cpu"
semantic_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2", device=device)

def semantic_chunk_text_GPU(text: str, similarity_threshold: float = 0.75, max_tokens: int = 500)-> list:
    """
    Splits text into semantic chunks based on sentence similarity and max token length
    """
    #break the page into sentences
    sentences = nltk.sent_tokenize(text) #list
    if not sentences:
        return []
    
    embeddings = semantic_model.encode(sentences, convert_to_tensor=True, device=device)
    
    chunks = []
    current_chunk = [sentences[0]]
    current_embeddings  = embeddings[0]

    for i in range(1, len(sentences)):
        #[0][0] takes the value of the cosine similarity
        sim = F.cosine_similarity(current_embeddings, embeddings[i], dim=0).item()
        chunk_token_count = len(" ".join(current_chunk)) // 4
        

        if sim >= similarity_threshold and chunk_token_count < max_tokens:
            current_chunk.append(sentences[i])
            #mean of the embeddings chunk
            #I keep only the mean of the embeedings of the chunk(not all the embeddings)
            #each chunk will have only one embedding(the mean of the similar embeddings)
            current_embeddings = torch.mean(torch.stack([current_embeddings, embeddings[i]]), dim=0)
        else:
            chunks.append(" ".join(current_chunk)) #string with the current chunk
            current_chunk = [sentences[i]]
            current_embeddings = embeddings[i]

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks
                                
    
from tqdm.auto import tqdm

def semantic_chunk_pdf_pages_GPU(pages_and_texts:list, similarity_threshold: float = 0.75, max_tokens: int = 500) -> list:
    """
    Takes pdf pages with text and splits them into semantic chunks.
    Returns a list of dicts with page_number, chunk_index, and chunk_text.
    """

    all_chunks = []
    for page in tqdm(pages_and_texts, desc = "Semantic Chunking"):
        page_number = page["page_number"]
        page_text = page["text"]

        chunks = semantic_chunk_text_GPU(page_text, similarity_threshold, max_tokens)

        for i,chunk in enumerate(chunks):
            all_chunks.append({
                "page_number": page_number,
                "chunk_index": i,
                "chunk_char_count": len(chunk),
                "chunk_word_count": len(chunk.split()),
                "chunk_token_count": len(chunk)/4,
                "chunk_text": chunk
            })

    return all_chunks
# Out:
# 2025-10-06 09:08:51,093 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2

# %%
semnatic_chunk_pages_GPU = semantic_chunk_pdf_pages_GPU(pages_and_texts, similarity_threshold = 0.75, max_tokens = 500)

print(f"Total semantic chunks: {len(semnatic_chunk_pages_GPU)}")
print(f"First semantic chunk page {semnatic_chunk_pages_GPU[0]['page_number']}")
print(semnatic_chunk_pages_GPU[0]['chunk_text'][:200])
# Out:
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 semnatic_chunk_pages_GPU = semantic_chunk_pdf_pages_GPU(pages_and_texts, similarity_threshold = 0.75, max_tokens = 500)
#       3 print(f"Total semantic chunks: {len(semnatic_chunk_pages_GPU)}")
#       4 print(f"First semantic chunk page {semnatic_chunk_pages_GPU[0]['page_number']}")
#
# Cell In[116], line 57, in semantic_chunk_pdf_pages_GPU(pages_and_texts, similarity_threshold, max_tokens)
#      54 page_number = page["page_number"]
#      55 page_text = page["text"]
# ---> 57 chunks = semantic_chunk_text_GPU(page_text, similarity_threshold, max_tokens)
#      59 for i,chunk in enumerate(chunks):
#      60     all_chunks.append({
#      61         "page_number": page_number,
#      62         "chunk_index": i,
#    (...)
# ...

# %%
pages = pages_and_texts[41:51]
print(type(pages))
print(type(pages[0]))
print(pages[0].keys())
print(pages[0]["text"])
# Out:
# <class 'list'>
# <class 'dict'>
# dict_keys(['page_number', 'page_char_count', 'page_word_count', 'page_sentence_count_raw', 'page_token_count', 'text'])
# Special Thanks to  Bill Chismar – University of Hawai’i at Mānoa, Dean of Outreach  College  The Children’s Healthy Living Summer Institute – University of  Hawai’i at Mānoa  Open Educational Resources  This text is provided to you as an Open Educational Resource (OER)  which you access online. It is designed to give you a comprehensive  introduction to human nutrition at no or very nominal cost.  It  contains both written and graphic text material, intra-text links to  other internal material which may aid in understanding topics and  concepts, intra-text links to the appendices and glossary for tables  and definitions of words, and extra-text links to videos and web  material that clarifies and augments topics and concepts.  xlii  |  Acknowledgements

# %% [markdown]
# ## Chunking strategy 3: Structured Chunking

# %%
import re
import random
import textwrap

def _is_chapter_title_page(text:str) -> bool:
    """
    Helper to detect "chapter start" pages
    """
    #check if the text contains a chapter title
    return re.search(r"university\s+of\s+hawai", text, flags=re.IGNORECASE) is not None

def _guess_title_from_page(text: str) -> str:
    """Best-effort guess of the chapter title = the text before the "University of Hawaii" header line
    Falls back to the ~120 characters
    """
    m = re.search(r"university\s+of\s+hawai", text, re.IGNORECASE)
    if m:
        title = text[:m.start()].strip()
        #keep it readable
        title = re.sub(r"\s+"," ", title).strip()
        if 10 <= len(title) <= 180:
            return title
        
    #fallback
    t = re.sub(r"\s+"," ",text).strip()
    return t[:120] if t else "Unknown Chapter"

def build_chapter_chunks(pages_and_texts:list) -> list:
    """
    Builds chapter chunks from the pages_and_texts list of dicts.
    """

    if not pages_and_texts:
        return []
    
    #find all the page indexes that look like the start of a chapter
    chapter_starts = []
    for index, page in enumerate(pages_and_texts):
        page_text = page["text"]
        if _is_chapter_title_page(page_text):
            chapter_starts.append(index)
    
    #if nothing detected, return empty (or treat entire doc as one chunk)
    if not chapter_starts:
        #Treat entire doc as one chunk - all text from all pages as 1 string(chunk)
        all_text = " ".join(page["text"] for page in pages_and_texts)
        return [{
            "chapter_index": 0,
            "title": _guess_title_from_page(pages_and_texts[0]["text"]),
            "page_start": pages_and_texts[0]["page_number"],
            "page_end": pages_and_texts[-1]["page_number"],
            "chunk_char_count": len(all_text),
            "chunk_word_count": len(all_text.split()),
            "chunk_token_count": round(len(all_text) / 4,2),
            "chunk_text": all_text
        }]
    
    #Build chapter range: START -> NEXT_START-1
    chapter_chunks = []
    for ci, s in enumerate(chapter_starts):
        # e will be the page index of the ending of the chapter
        # e+1 is the index of the first page of the next chapter
        # chapter_starts[ci+1] is the page index of the next chapter;
        # if there is no next chapter, e will be the last page index(len(pages_and_texts) - 1)
        e = (chapter_starts[ci + 1] - 1) if (ci + 1 < len(chapter_starts)) else (len(pages_and_texts) - 1)
        if e < s:
            continue

        pages = pages_and_texts[s:e+1]
        text_concat = " ".join(page["text"] for page in pages).strip() 
                    # all the text from the pages(start index = s, end index = e) in the chapter in one string
        title = _guess_title_from_page(pages[0]["text"])

        chapter_chunks.append({
            "chapter_index": ci,
            "title": title,
            "page_start": pages[0]["page_number"],
            "page_end": pages[-1]["page_number"],
            "chunk_char_count": len(text_concat),
            "chunk_word_count": len(text_concat.split()),
            "chunk_token_count": round(len(text_concat) / 4,2),
            "chunk_text": text_concat
        })

    return chapter_chunks

# %%
structure_chunked_pages = build_chapter_chunks(pages_and_texts)
print(f"Total chapter chunks: {len(structure_chunked_pages)}")
print(f"First chapter chunk: {structure_chunked_pages[84]['title']}")
# Out:
# Total chapter chunks: 171
# First chapter chunk: Ahi poke by Arnold Gatilao / CC BY 2.0 Introduction

# %% [markdown]
# ## Chunking Strategy 4: RECURSIVE STRUCTURED Chunking -> DOCLING

# %%
from docling.document_converter import DocumentConverter


def extract_pdf_with_docling(pdf_path:str) -> str:
    """
    Extracts the text from a pdf file using the docling library.
    """
    try:
        if not os.path.exists(pdf_path):
            raise FileNotFoundError(f"File not found: {pdf_path}")
        
        converter = DocumentConverter()
        result = converter.convert(pdf_path)
        markdown_text = result.document.export_to_markdown()
        return markdown_text
    except Exception as e:
        print(f"Error extracting PDF with Docling: {e}")
        return ""

# %%
pdf_path = "../data/human_nutrition.pdf"
markdown_text = extract_pdf_with_docling(pdf_path)
# Out:
# 2025-10-06 09:32:43,974 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-06 09:32:44,044 - INFO - Going to convert document batch...
# 2025-10-06 09:32:44,045 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-06 09:32:44,061 - INFO - Loading plugin 'docling_defaults'
# 2025-10-06 09:32:44,062 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-10-06 09:32:44,069 - INFO - Loading plugin 'docling_defaults'
# 2025-10-06 09:32:44,072 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-10-06 09:32:44,240 - INFO - Accelerator device: 'mps'
# 2025-10-06 09:32:46,725 - INFO - Accelerator device: 'mps'
# 2025-10-06 09:32:48,124 - INFO - Accelerator device: 'mps'
# 2025-10-06 09:32:48,699 - INFO - Processing document human_nutrition.pdf
# 2025-10-06 09:45:22,335 - INFO - Finished converting document human_nutrition.pdf in 758.35 sec.

# %%
markdown_cv = extract_pdf_with_docling("../data/CV_Boiciuc_Tyby-Dany.pdf")
print(markdown_cv)
# Out:
# 2025-10-05 16:24:20,863 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-05 16:24:20,891 - INFO - Going to convert document batch...
# 2025-10-05 16:24:20,892 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-05 16:24:20,898 - INFO - Loading plugin 'docling_defaults'
# 2025-10-05 16:24:20,899 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-10-05 16:24:20,905 - INFO - Loading plugin 'docling_defaults'
# 2025-10-05 16:24:20,908 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-10-05 16:24:21,014 - INFO - Accelerator device: 'mps'
# 2025-10-05 16:24:23,548 - INFO - Accelerator device: 'mps'
# 2025-10-05 16:24:25,085 - INFO - Accelerator device: 'mps'
# 2025-10-05 16:24:25,474 - INFO - Processing document CV_Boiciuc_Tyby-Dany.pdf
# 2025-10-05 16:24:26,614 - INFO - Finished converting document CV_Boiciuc_Tyby-Dany.pdf in 5.75 sec.
# ...

# %%
import nltk
from tqdm.auto import tqdm



def recursive_chunk_text(text:str, max_chunk_size:int = 1000) -> list:
    """
    Recursively splits a block of text into chunks that fit within size constraints.
    Tries splitting by sections, then newlines, then sentences.
    """
    def split_chunk(chunk: str) -> list:
        if len(chunk) <= max_chunk_size:
            return [chunk]
    
        # Try splitting by sections
        sections = chunk.split("##")
        if len(sections) > 1:
            result = []
            for section in sections:
                if section.strip():
                    # print(f"Split chunk: {section.strip()}")
                    result.extend(split_chunk(section.strip()))
            return result
        
        # Try splitting by single newline
        sections = chunk.split("\n")
        if len(sections) > 1:
            result = []
            for section in sections:
                if section.strip():
                    # print(f"Split chunk by newline: {section.strip()}")
                    result.extend(split_chunk(section.strip()))
            return result
        
        # Fallback: split by sentences
        sentences = nltk.sent_tokenize(chunk) #list of sentences
        chunks, current_chunk, current_size = [], [], 0
        #chunk will be the final list of chunks
        #current_chunk will be the temporary chunk that we are building and adding to the final list
        
        for sentence in sentences:
            if current_size + len(sentence) > max_chunk_size:
                if current_chunk:
                    chunks.append(" ".join(current_chunk)) #" ".join(current_chunk) will join the 
                                                    # entire list into a string(one element)
                current_chunk = [sentence]
                current_size = len(sentence)
            else:
                current_chunk.append(sentence)
                current_size += len(sentence)
        
        if current_chunk:
            chunks.append(" ".join(current_chunk))
            
        return chunks

    return split_chunk(text)

# %%
recursive_chunked_pages = recursive_chunk_text(markdown_text)
print(f"length of the recursive_chunked_text: {len(recursive_chunked_pages)}")
print(f"First chunk length: {len(recursive_chunked_pages[0])}")
print(f"Last chunk length: {len(recursive_chunked_pages[-1])}")
# Out:
# length of the recursive_chunked_text: 6459
# First chunk length: 45
# Last chunk length: 132

# %%
def combine_small_chunks_optimized(chunks: list, min_chunk_size: int = 200) -> list:
    """Combine small chunks(consecutive titles and subtitles) into larger chunks"""
    if not chunks:
        return []
    
    result = []
    current_combined = ""
    
    for chunk in chunks:
        if len(chunk) < min_chunk_size:
            # Combine with the current chunk
            if current_combined:    
                current_combined += " " + chunk
            else:
                current_combined = chunk
        else:
            # The chunk is large, save the combined chunk and add the large chunk
            if current_combined:
                result.append(current_combined)
                current_combined = ""
            result.append(chunk)
    
    # Save the last combined chunk
    if current_combined:
        result.append(current_combined)
    
    return result

combined_chunks = combine_small_chunks_optimized(recursive_chunked_text)
print(f"Number of chunks after combining: {len(combined_chunks)}")
print(f"First chunk: {combined_chunks[0]}")
print(f"Last chunk: {combined_chunks[-1]}")
# Out:
# Number of chunks after combining: 3291
# First chunk: Human Nutrition: 2020 Edition
#
# <!-- image -->
# ...

# %% [markdown]
# ## Chunking Strategy 5: LLM based Chunking

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_NAME = "Qwen/Qwen3-0.6B"
DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

TOKENIZER = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
MODEL = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    trust_remote_code=True,
    torch_dtype=torch.float16 if DEVICE.type == "mps" else None,
    low_cpu_mem_usage=True,
).to(DEVICE)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def llm_based_chunking(text:str, chunk_size: int, max_new_tokens:int = 1024, model = MODEL) -> list:
    """
    Analyzes the text and identifies the best points to split it into two semantically coherent chunks.
    Returns the integer index within the text where the split should occur.
    """

    def get_chunk_boundaries(text_segment:str) -> str:
        # prepare input
        prompt = f"""
        Analyze the following text and identify the best points to split it into two semantically coherent chunks.
        The split should accur near 1000 characters.

        Text:
        \"\"\"{text_segment}\"\"\"\"

        Return only the integer indexes within this text where split should occur.
        output format: a single integer and nothing else.

        """
        messages = [
            {"role": "system", "content": "You are a helpful assistant that can analyze text and identify the best points to split it into two semantically coherent chunks."},
            {"role": "user", "content": prompt}]

        text = TOKENIZER.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=False
        )

        inputs = TOKENIZER([text], return_tensors="pt").to(DEVICE)

        # generate
        with torch.inference_mode():
            outputs = MODEL.generate(
                **inputs,
                use_cache = True, #Enable KV cache (store the result of the previous tokens-it wont calculate the Q,K,V for the same tokens)
                max_new_tokens=max_new_tokens,  
                do_sample=True,
                temperature=0.1
            )

        # parse output
        output_ids = outputs[0][len(inputs.input_ids[0]):].tolist()

        try:
            index = len(output_ids) - output_ids[::-1].index(151668)  # </think>
        except ValueError:
            index = 0

        # thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
        content = TOKENIZER.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

        # print("thinking content:", thinking_content)
        # print("content:", content)
        try:
            split_point = int(content)
        except ValueError:
            split_point = chunk_size
        return split_point

    chunks = []
    remaining_text = text

    while len(remaining_text) > chunk_size:
        text_window = remaining_text[:chunk_size * 2]
        split_point = get_chunk_boundaries(text_window)

        #safety check
        if split_point < 100 or split_point > len(text_window) - 100:
            split_point = chunk_size
        
        chunks.append(remaining_text[:split_point].strip())
        remaining_text = remaining_text[split_point:].strip()

    if remaining_text:
        chunks.append(remaining_text)

    return chunks


def llm_based_chunking_pdf_pages(pages_and_texts:list, chunk_size:int = 1000) -> list:
    all_chunks = []
    for page in pages_and_texts:
        page_index= page["page_number"]
        page_text = page["text"]

        chunks = llm_based_chunking(page_text, chunk_size, max_new_tokens=1024)
        for index,chunk in enumerate(chunks):
            all_chunks.append({
                "page_number": page_index,
                "chunk_index": index,
                "chunk_char_count": len(chunk),
                "chunk_word_count": len(chunk.split()),
                "chunk_token_count": len(chunk)/4,
                "chunk_text": chunk
            })
    return all_chunks

# %%
llm_chunked_pages = llm_based_chunking_pdf_pages(pages_and_texts, chunk_size=1000)
print(len(llm_chunked_pages))
# Out:
# 2205

# %%
print(len(llm_chunked_pages))
print(llm_chunked_pages[20]["chunk_text"])
# Out:
# 2205
# Discovering Nutrition Facts  University of Hawai‘i at Mānoa Food Science and  Human Nutrition Program and Human Nutrition  Program  718  Building Healthy Eating Patterns  University of Hawai‘i at Mānoa Food Science and  Human Nutrition Program and Human Nutrition  Program  740  MyPlate Planner  University of Hawai‘i at Mānoa Food Science and  Human Nutrition Program and Human Nutrition  Program  745  Pacific Based Dietary Guidelines  University of Hawai‘i at Mānoa Food Science and  Human Nutrition Program and Human Nutrition  Program  760  Understanding the Bigger Picture of Dietary  Guidelines  University of Hawai‘i at Mānoa Food Science and  Human Nutrition Program and Human Nutrition  Program  768  Part XIII. Chapter 13. Lifespan Nutrition From  Pregnancy

# %% [markdown]
# ## Analysis of Chunking Strategies

# %%
#Build stats + plots directly from your existing lists
#fixed_chunked_pages, semantic_chunk_pages, structure_chunked_pages, recursive_chunked_pages,llm_chunked_pages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#----Config: choose which size metric to analyze-----
#one of "chars" (chunk_char_count), "words" (chunk_words_count), "tokens" (chunk_token_count)
METRIC = "tokens"

#----Config: choose which chunks to analyze-----
#all_chunks, semantic_chunk_pages, recursive_chunked_pages,llm_chunked_pages
def _size_val(c, metric = str):
    if metric == "chars":
        return c.get("chunk_char_count", len(c.get("chunk_text", ""))) #number of characters or 0
        #return c.get("chunk_char_count")
    elif metric == "words":
        return c.get("chunk_word_count", len(c.get("chunk_text", "").split()))
    elif metric == "tokens":
        return c.get("chunk_token_count", len(c.get("chunk_text", ""))/4)
    else:
        raise ValueError(f"Metric must be one of: {'chars', 'words', 'tokens'}")


def analyze_chunks(chunks = list[dict], method_name = str, metric = str) -> dict:

    sizes = [_size_val(c, metric) for c in chunks]
    return {
        "Method": method_name,
        "Avg_chunk_size": float(np.mean(sizes)) if sizes else 0,
        "Num_chunks": len(sizes),
        "Size_variance": float(np.var(sizes)) if sizes else 0,
    }

dataset = [
    ("fixed", fixed_chunked_pages),
    ("semantic", semantic_chunk_pages),
    ("structure", structure_chunked_pages),
    ("llm", llm_chunked_pages)
]

results = [analyze_chunks(chunks, method_name, METRIC) for method_name, chunks in dataset]
df = pd.DataFrame(results)
print(df.round(3).to_string(index=False))
# Out:
#    Method  Avg_chunk_size  Num_chunks  Size_variance
#     fixed         101.733        3321       1338.255
#  semantic          28.544       12016        674.005
# structure        2028.912         171    4736630.888
#       llm         157.184        2205       7108.934

# %% [markdown]
# Performance Analysis
# 1. Structure-based chunking produced the most coherent sections.
# 2. Semantic chunking maintained best context preservation.
# 3. Fixed-size chunking provided balanced results but poor semantic coherence

# %%
# --- Bar plots ----

fig, axes = plt.subplots(1, 3, figsize = (18,5))

axes[0].bar(df["Method"], df["Avg_chunk_size"], color = "skyblue")
axes[0].set_title("Average Chunk Size")
axes[0].set_ylabel({"chars":"Characters", "words":"Words", "tokens":"Tokens"}[METRIC])

axes[1].bar(df["Method"], df["Num_chunks"], color = "skyblue")
axes[1].set_title("Number of Chunks")
axes[1].set_ylabel("Count")

axes[2].bar(df["Method"], df["Size_variance"], color = "skyblue")
axes[2].set_title("Chunk Size Variance")
axes[2].set_ylabel("Variance")

plt.suptitle("Chunking Method Comparison (metric: {METRIC})")
plt.tight_layout()
plt.show()

# %% [markdown]
# Structured-based chunking -> Produced the largest chunks, fewer in number, but with veru high variance
#     Best for capturing entire sections/chapters, less balanced for downstram models
#
# Semantic chunking -> Produced very small chunks and the highest number of chunks.Preserves fine-grained context, but risks over-fragmentation
#
# Fixed-size chunking -> Produced consistent, moderate chunks with low variance. Ignores semantic boundaries.
#
# LLM chunking -> Produced moderate number of chunks with moderate variance, but required highest computational time.
